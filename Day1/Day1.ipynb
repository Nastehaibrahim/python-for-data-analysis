# %% [markdown]
# import library

# %%
#import library
#Syntex for import
import pandas as pd

# %% [markdown]
# load dataset

# %%
data=pd.read_excel("/content/drive/MyDrive/Colab Notebooks/airline project.xlsx")

# %% [markdown]
# understanding dataset

# %%
Data.shape
# Out:
# (24, 9)

# %%
Data.head(10)
# Out:
#    No.              Student Name  \
# 0    1        Aba Muxudiin Ahmed
# 1    2      Abdikarim Ismail Ali
# 2    3  Abdinajib Abdullahi Muse
# 3    4   Aisha Mohamed Abdullahi
# 4    5       Aniso Ahmed Mohamud
# 5    6      Axmed Abduqadir Iman
# 6    7   Ayuub Abdullahi Isxaakh
# 7    8    Cayni Abuukar Maxamuud
# 8    9  Deqo Abdulkhadir Hussein
# 9   10     Faadumo Mahamed Yusuf
#
#                                        Project Title      Dataset Sheet  Rows  \
# 0       Student Enrollment Data Analysis Using Excel      01_Enrollment   300
# 1  Customer Purchase & Sales Performance Analysis...           02_Sales   300
# 2      Employee Attendance Data Analysis Using Excel  03_Emp_Attendance   300
# 3  Restaurant Sales and Customer Analysis Using E...      04_Restaurant   300
# 4                                 TITLE NOT PROVIDED                NaN     0
# 5  Electricity Consumption Data Analysis Using Excel     06_Electricity   300
# ...

# %%
Data.tail(5)
# Out:
#     No.              Student Name  \
# 19   20  Nimca Abdiraxman Wehliye
# 20   21    Omar Abdullahi Mohamed
# 21   22         Ramla Abdi Osmaan
# 22   23     Shukri idiris mahamed
# 23   24        Sucdi Yasin Husein
#
#                                    Project Title   Dataset Sheet  Rows  \
# 19              Marketing Campaign Data Analysis    20_Marketing   300
# 20       Bank Customer Data Analysis Using Excel         21_Bank   300
# 21  Insurance Customer Data Analysis Using Excel    22_Insurance   300
# 22                Crime Statistics Data Analysis        23_Crime   300
# 23   Job Recruitment and Applicant Data Analysis  24_Recruitment   300
#
#     Columns Status  Unnamed: 7 Data Quality Note
# 19        7  Ready         NaN               NaN
# 20        7  Ready         NaN               NaN
# 21        7  Ready         NaN               NaN
# 22        7  Ready         NaN               NaN
# 23        7  Ready         NaN               NaN

# %% [markdown]
# dispaly all colmns names

# %%
Data.columns
# Out:
# Index(['No.', 'Student Name', 'Project Title', 'Dataset Sheet', 'Rows',
#        'Columns', 'Status', 'Unnamed: 7', 'Data Quality Note'],
#       dtype='object')

# %% [markdown]
# display the datatype using property(datatype)

# %%
Data.dtypes
# Out:
# No.                    int64
# Student Name          object
# Project Title         object
# Dataset Sheet         object
# Rows                   int64
# Columns                int64
# Status                object
# Unnamed: 7           float64
# Data Quality Note     object
# dtype: object

# %% [markdown]
# summary of datafarme

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   No.                24 non-null     int64
#  1   Student Name       24 non-null     object
#  2   Project Title      24 non-null     object
#  3   Dataset Sheet      23 non-null     object
#  4   Rows               24 non-null     int64
#  5   Columns            24 non-null     int64
#  6   Status             24 non-null     object
#  7   Unnamed: 7         0 non-null      float64
#  8   Data Quality Note  1 non-null      object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 1.8+ KB

# %% [markdown]
# display the describe

# %%
Data.describe()
# Out:
#              No.        Rows    Columns  Unnamed: 7
# count  24.000000   24.000000  24.000000         0.0
# mean   12.500000  287.500000   6.708333         NaN
# std     7.071068   61.237244   1.428869         NaN
# min     1.000000    0.000000   0.000000         NaN
# 25%     6.750000  300.000000   7.000000         NaN
# 50%    12.500000  300.000000   7.000000         NaN
# 75%    18.250000  300.000000   7.000000         NaN
# max    24.000000  300.000000   7.000000         NaN
